# %%
import pandas as pd
import numpy as np

# %%
df1=read_excel(r"/content/Sample - Superstore.xlsx")
df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4e00ff151c15> in <cell line: 0>()
# ----> 1 df1=read_excel(r"/content/Sample - Superstore.xlsx")
#       2 df1.head()
#
# NameError: name 'read_excel' is not defined

# %%
import pandas as pd
import numpy as np

df1 = pd.read_excel(r"/content/Sample - Superstore.xlsx")  # Use pd.read_excel() to call the function
df1.head()
# Out:
#      A`        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  4962  CA-2016-156587 2016-03-07 2016-03-08     First Class    AB-10015
# 1  4963  CA-2016-156587 2016-03-07 2016-03-08     First Class    AB-10015
# 2  4964  CA-2016-156587 2016-03-07 2016-03-08     First Class    AB-10015
# 3  8223  CA-2016-152905 2016-02-18 2016-02-24  Standard Class    AB-10015
# 4  8802  CA-2018-140935 2018-11-10 2018-11-12     First Class    AB-10015
#
#    Customer Name   Segment Country/Region           City  ... Postal Code  \
# 0  Aaron Bergman  Consumer  United States        Seattle  ...     98103.0
# 1  Aaron Bergman  Consumer  United States        Seattle  ...     98103.0
# 2  Aaron Bergman  Consumer  United States        Seattle  ...     98103.0
# 3  Aaron Bergman  Consumer  United States      Arlington  ...     76017.0
# 4  Aaron Bergman  Consumer  United States  Oklahoma City  ...     73120.0
#
#     Region       Product ID         Category Sub-Category  \
# ...

# %%
df1[df1['Order Id']=='Region']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Order Id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-e7295a64e3ef> in <cell line: 0>()
# ----> 1 df1[df1['Order Id']=='Region']
#
# ...

# %%
df1[df1['Order ID']=='Region']  # Change 'Order Id' to 'Order ID'
# Out:
# Empty DataFrame
# Columns: [A`, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country/Region, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
df2=pd.read_csv(r"/content/fact_bating_summary.csv")
df2.head()
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
#
#   out/not_out  runs  balls  4s  6s      SR
# 0         out    32     27   3   1  118.51
# 1         out    86     59   7   3  145.76
# 2         out    31     15   0   3  206.66
# 3     not_out    37     20   2   3  185.00
# 4         out    51     43   6   0  118.60

# %%
df2.columns
# Out:
# Index(['match_id', 'match', 'teamInnings', 'battingPos', 'batsmanName',
#        'out/not_out', 'runs', 'balls', '4s', '6s', 'SR'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3268 entries, 0 to 3267
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   match_id     3268 non-null   object
#  1   match        3268 non-null   object
#  2   teamInnings  3268 non-null   object
#  3   battingPos   3268 non-null   int64
#  4   batsmanName  3268 non-null   object
#  5   out/not_out  3268 non-null   object
#  6   runs         3268 non-null   int64
#  7   balls        3268 non-null   int64
#  8   4s           3268 non-null   int64
#  9   6s           3268 non-null   int64
#  10  SR           3268 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 281.0+ KB

# %%
df2.describe()
# Out:
#         battingPos         runs        balls           4s           6s
# count  3268.000000  3268.000000  3268.000000  3268.000000  3268.000000
# mean      4.772032    19.820073    14.700734     1.744798     0.875459
# std       2.714852    21.885699    13.516978     2.329142     1.426316
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     3.000000     4.000000     0.000000     0.000000
# 50%       4.000000    12.000000    10.000000     1.000000     0.000000
# 75%       7.000000    29.000000    21.000000     3.000000     1.000000
# max      11.000000   140.000000    70.000000    16.000000    10.000000

# %%
df2.tail(1)
# Out:
#      match_id                  match teamInnings  battingPos batsmanName  \
# 3267  T201566  Super Kings Vs Titans      Titans           7  RashidKhan
#
#      out/not_out  runs  balls  4s  6s      SR
# 3267     not_out    10      3   1   1  333.33

# %%
df2.head(10)
# Out:
#   match_id               match  teamInnings  battingPos     batsmanName  \
# 0  T203817  Super Kings Vs KKR  Super Kings           1  RuturajGaikwad
# 1  T203817  Super Kings Vs KKR  Super Kings           2    FafduPlessis
# 2  T203817  Super Kings Vs KKR  Super Kings           3    RobinUthappa
# 3  T203817  Super Kings Vs KKR  Super Kings           4        MoeenAli
# 4  T203817  Super Kings Vs KKR          KKR           1     ShubmanGill
# 5  T203817  Super Kings Vs KKR          KKR           2   VenkateshIyer
# 6  T203817  Super Kings Vs KKR          KKR           3      NitishRana
# 7  T203817  Super Kings Vs KKR          KKR           4     SunilNarine
# 8  T203817  Super Kings Vs KKR          KKR           5      EoinMorgan
# 9  T203817  Super Kings Vs KKR          KKR           6   DineshKarthik
#
#   out/not_out  runs  balls  4s  6s      SR
# 0         out    32     27   3   1  118.51
# 1         out    86     59   7   3  145.76
# 2         out    31     15   0   3  206.66
# ...

# %%
df2.balls
# Out:
# 0       27
# 1       59
# 2       15
# 3       20
# 4       43
#         ..
# 3263    17
# 3264    11
# 3265    21
# 3266    14
# 3267     3
# Name: balls, Length: 3268, dtype: int64

# %%
df2['balls']
# Out:
# 0       27
# 1       59
# 2       15
# 3       20
# 4       43
#         ..
# 3263    17
# 3264    11
# 3265    21
# 3266    14
# 3267     3
# Name: balls, Length: 3268, dtype: int64

# %%
df2.balls.min()
# Out:
# 0

# %%
df2.balls.max()
# Out:
# 70

# %%
df2['6s'].mean()
# Out:
# 0.8754589963280294

# %%
df2[df2['batsmanName']=='FafduPlessis']
# Out:
#      match_id                        match  teamInnings  battingPos  \
# 1     T203817           Super Kings Vs KKR  Super Kings           2
# 56    T201819      Capitals Vs Super Kings  Super Kings           2
# 113   T201866  Super Kings Vs Punjab Kings  Super Kings           2
# 158   T207682      Super Kings Vs Capitals  Super Kings           2
# 207   T205672        Super Kings Vs Royals  Super Kings           2
# 260   T203061     Sunrisers Vs Super Kings  Super Kings           2
# 353   T202406           KKR Vs Super Kings  Super Kings           2
# 404   T207776           RCB Vs Super Kings  Super Kings           2
# 468   T201256        Super Kings Vs Mumbai  Super Kings           2
# 515   T203694        Super Kings Vs Mumbai  Super Kings           2
# 575   T205094     Sunrisers Vs Super Kings  Super Kings           2
# 611   T202915           Super Kings Vs RCB  Super Kings           2
# 668   T202233           Super Kings Vs KKR  Super Kings           2
# ...

# %%
df2[['teamInnings','match']]
# Out:
#       teamInnings                  match
# 0     Super Kings     Super Kings Vs KKR
# 1     Super Kings     Super Kings Vs KKR
# 2     Super Kings     Super Kings Vs KKR
# 3     Super Kings     Super Kings Vs KKR
# 4             KKR     Super Kings Vs KKR
# ...           ...                    ...
# 3263       Titans  Super Kings Vs Titans
# 3264       Titans  Super Kings Vs Titans
# 3265       Titans  Super Kings Vs Titans
# 3266       Titans  Super Kings Vs Titans
# 3267       Titans  Super Kings Vs Titans
#
# [3268 rows x 2 columns]

# %%
df2[['batsmanName','runs','teamInnings']][df2['6s']>=6]
# Out:
#           batsmanName  runs   teamInnings
# 120           KLRahul    98  Punjab Kings
# 499        JosButtler   124        Royals
# 518      AmbatiRayudu    72   Super Kings
# 524     KieronPollard    87        Mumbai
# 666   DevduttPadikkal   101           RCB
# ...               ...   ...           ...
# 3032   NicholasPooran    62  Super Giants
# 3063       RinkuSingh    48           KKR
# 3197     FafduPlessis    73           RCB
# 3218       KyleMayers    73  Super Giants
# 3253   RuturajGaikwad    92   Super Kings
#
# [61 rows x 3 columns]

# %%
df2[df2['teamInnings']=='RCB'][['4s','6s','runs']]
# Out:
#       4s  6s  runs
# 31     2   0    21
# 32     5   0    39
# 33     0   0     9
# 34     1   0    15
# 35     1   0    11
# ...   ..  ..   ...
# 3136   2   1    17
# 3196   6   5    82
# 3197   5   6    73
# 3198   0   0     0
# 3199   0   2    12
#
# [350 rows x 3 columns]

# %%
df2[['teamInnings','batsmanName','runs','balls']][(df2['runs']>60) & (df2['balls']<120)].head(5)
# Out:
#     teamInnings     batsmanName  runs  balls
# 1   Super Kings    FafduPlessis    86     59
# 55  Super Kings  RuturajGaikwad    70     50
# 57  Super Kings    RobinUthappa    63     44
# 71          RCB    SrikarBharat    78     52
# 75       Mumbai     IshanKishan    84     32

# %%
df2[['teamInnings','batsmanName','runs','balls']][(df2['runs']>60)][df2['teamInnings']=='RCB'].head(10)
# Out:
# <ipython-input-46-074019dbd962>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2[['teamInnings','batsmanName','runs','balls']][(df2['runs']>60)][df2['teamInnings']=='RCB'].head(10)
#      teamInnings      batsmanName  runs  balls
# 71           RCB     SrikarBharat    78     52
# 397          RCB  DevduttPadikkal    70     50
# 583          RCB     ABdeVilliers    75     42
# 665          RCB       ViratKohli    72     47
# 666          RCB  DevduttPadikkal   101     52
# 751          RCB     GlennMaxwell    78     49
# 752          RCB     ABdeVilliers    76     34
# 951          RCB     RajatPatidar   112     54
# 1031         RCB       ViratKohli    73     54
# 1240         RCB     FafduPlessis    73     50

# %%
df2.groupby('batsmanName')['runs'].sum().nlargest(5)
# Out:
# batsmanName
# ShubmanGill       1851
# FafduPlessis      1831
# RuturajGaikwad    1593
# KLRahul           1516
# JosButtler        1509
# Name: runs, dtype: int64

# %%
df2.groupby('batsmanName')['runs'].sum().nlargest(5)
